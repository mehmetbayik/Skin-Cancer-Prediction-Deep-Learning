# %%
import os
import datetime
import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib.colors import Normalize,LinearSegmentedColormap

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import sklearn.exceptions
from sklearn.utils import class_weight
warnings.filterwarnings("ignore", category=sklearn.exceptions.UndefinedMetricWarning)
import tensorflow as tf
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D, ZeroPadding2D
from keras.models import Model,Sequential
from keras.optimizers import Adam,SGD,RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# import tensorflow_addons as tfa
#finish_sound = "afplay /Users/mehmet/Documents/vs-code/winsquare.mp3"
# !jupyter nbconvert --to html skin-cancer-cnn.ipynb

# %% [markdown]
# # Data Augmentation

# %%
df=pd.read_csv('dataverse_files/HAM10000_metadata.csv')

df_unique = df.copy()
df_unique.drop_duplicates( subset=['lesion_id'], keep=False, inplace=True)
df_unique=df_unique.drop([ 'lesion_id','dx_type', 'age', 'sex', 'localization', 'dataset'], axis=1)
df_unique = df_unique.reset_index(drop=True)
df=df.drop([ 'lesion_id','dx_type', 'age', 'sex', 'localization', 'dataset'], axis=1)

train_df, val_df = train_test_split(df, train_size=0.9, shuffle=True, random_state=123, stratify=df['dx'])
train_df_unique, val_df_unique = train_test_split(df_unique, train_size=0.9, shuffle=True, random_state=123, stratify=df_unique['dx'])
df.shape, train_df.shape, val_df.shape, df_unique.shape, train_df_unique.shape, train_df_unique.shape
# Out:
# ((10015, 2), (9013, 2), (1002, 2), (5514, 2), (4962, 2), (4962, 2))

# %%
#plotting class distribution for lesion_id and image_id before rebalancing the class
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
bins = np.linspace(0 - .25, 6 + .25, 14)

# Plotting class distribution for training set

ax1.hist(train_df['dx'].sort_values(),bins=bins)
ax1.hist(train_df_unique['dx'].sort_values(),bins=bins)
ax1.set_title("Class Distribution for Training Set")
ax1.set_xlabel('Class Labels')
ax1.set_ylabel('Number of Images')
ax1.legend(['Extra Images for Same Lesions', 'Unique Lesions'])

# Plotting class distribution  for val set
ax2.hist(val_df['dx'].sort_values(),bins=bins)
ax2.hist(val_df_unique['dx'].sort_values(),bins=bins)
ax2.set_title("Class Distribution for Validation Set")
ax2.set_xlabel('Class Labels')
ax2.set_ylabel('Number of Images')
ax2.legend(['Extra Images for Same Lesions', 'Unique Lesions'])

plt.tight_layout()
plt.savefig('class_distribution.png')
plt.show()

# %%
def random_augment(image):
    tf.random.set_seed(123)
    # Randomly applied horizontal flip - reasonable for skin images
    image = tf.image.random_flip_left_right(image)
    
    # Random brightness - simulate different lighting conditions
    image = tf.image.random_brightness(image, max_delta=0.1)
    
    # Random contrast - simulate variations in camera quality and settings
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)

    # Random rotation - lesions can be oriented in any direction
    image = tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))

    # Gaussian blur - simulate slight focus variations
    # image = tfa.image.gaussian_filter2d(image, filter_shape=(3, 3), sigma=1.0)
    
    return image

# %%
def augmentention_on_dataset(df, df_unique, dataset_type, images_directory, max_sample, min_sample, ):
    df_unique = df_unique
    for label in df['dx'].unique():
        df_label = df[df['dx'] == label]
        df_unique_label = df_unique[df_unique['dx'] == label]
    
        #If in the label is more than n images we delete all duplicates and sometimes part of random unique imagas
        if(len(df_label) > max_sample):
            df = pd.concat([df[df['dx'] != label], df_unique[df_unique['dx'] == label]])
            df_label = df[df['dx'] == label]
            drop_indices = np.random.choice(df[df['dx'] == label].index, len(df_label) - max_sample, replace=False)
            df = pd.concat([df[df['dx'] != label], df_label.drop(drop_indices)])
        
        #If in the label is less than n images we randomly choose unique images for augmentation
        if(len(df_label) < min_sample):
            selected_indices = np.random.choice(df_unique_label.index, min_sample - len(df_label), replace=True)
            df_to_add = df_unique_label.loc[selected_indices]
            df_to_add['image_id'] = df_to_add['image_id'] + '-' + dataset_type + (df_to_add.groupby('image_id').cumcount() + 1).astype(str)
            df = pd.concat([df, df_to_add])
        
    for i in df[df['image_id'].str.len() > 12]['image_id'].values:
        image = tf.io.read_file(os.path.join(images_directory, i.split('-')[0] + '.jpg'))
        image = tf.image.decode_jpeg(image, channels=3)
    
        # Apply augmentations
        augmented_image = random_augment(image)
    
        # Convert back to image format and save the augmented image
        augmented_image = tf.cast(augmented_image, tf.uint8)
        augmented_image = tf.image.encode_jpeg(augmented_image)
        tf.io.write_file(os.path.join(images_directory, i + '.jpg'), augmented_image)
    
    df['image_id'] = df['image_id'].astype(str) + '.jpg'
    df.to_csv(f'dataverse_files/HAM10000_metadata_modified_' + dataset_type +'.csv')

# %%
augmentention_on_dataset(train_df, train_df_unique, 'train_df', 
                         os.path.join(os.getcwd(), "dataverse_files/HAM10000_images_augmented"), 1350, 720)

# %%
augmentention_on_dataset(val_df, val_df_unique, 'val_df', 
                         os.path.join(os.getcwd(), "dataverse_files/HAM10000_images_augmented"), 150, 80)

# %%
train_df_unique_augmented = pd.read_csv('dataverse_files/HAM10000_metadata_modified_train_df.csv')
val_df_unique_augmented = pd.read_csv('dataverse_files/HAM10000_metadata_modified_val_df.csv')
train_df_unique_augmented = train_df_unique_augmented.drop(['Unnamed: 0'], axis=1)
val_df_unique_augmented = val_df_unique_augmented.drop(['Unnamed: 0'], axis=1)
train_df_unique_augmented.head()
# Out:
#            image_id   dx
# 0  ISIC_0032072.jpg  mel
# 1  ISIC_0033829.jpg  bkl
# 2  ISIC_0029163.jpg  mel
# 3  ISIC_0026205.jpg  bkl
# 4  ISIC_0025661.jpg  bkl

# %%
#plotting class distribution for lesion_id and image_id after rebalancing the class
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
bins = np.linspace(0 - .25, 6 + .25, 14)

# Plotting class distribution for training set

ax1.hist(train_df_unique['dx'].sort_values(),bins=bins)
ax1.hist(train_df_unique_augmented['dx'].sort_values(),bins=bins)
ax1.set_title("Class Distribution for Training Set")
ax1.set_xlabel('Class Labels')
ax1.set_ylabel('Number of Images')
ax1.legend(['Extra Images for Same Lesions', 'Unique Lesions'])

# Plotting class distribution  for val set
ax2.hist(train_df_unique['dx'].sort_values(),bins=bins)
ax2.hist(train_df_unique_augmented['dx'].sort_values(),bins=bins)
ax2.set_title("Class Distribution for Validation Set")
ax2.set_xlabel('Class Labels')
ax2.set_ylabel('Number of Images')
ax2.legend(['Extra Images for Same Lesions', 'Unique Lesions'])

plt.tight_layout()
plt.savefig('class_distribution_augmented.png')
plt.show()

# %%
test_df = pd.read_csv('dataverse_files/ISIC2018_Task3_Test_GroundTruth.csv')
test_df = test_df.drop([ 'lesion_id','dx_type', 'age', 'sex', 'localization', 'dataset'], axis=1)
# if your image names have no extension
test_df['image_id'] = test_df['image_id'].astype(str) + '.jpg'
# 'ISIC_0035068.jpg' is missing in the dataset, lets remove it from test set
test_df = test_df[test_df['image_id'] != 'ISIC_0035068.jpg']
test_df.head()
# Out:
#            image_id   dx
# 0  ISIC_0034524.jpg   nv
# 1  ISIC_0034525.jpg   nv
# 2  ISIC_0034526.jpg  bkl
# 3  ISIC_0034527.jpg   nv
# 4  ISIC_0034528.jpg   nv

# %%
rescale=1./255
color_mode = 'rgb'
target_size = (28, 28)
batch_size  = 64
# 600 x 450

train_datagen = ImageDataGenerator(rescale=rescale)
train_set = train_datagen.flow_from_dataframe(train_df_unique_augmented,
                                              directory="dataverse_files/HAM10000_images_augmented",
                                              x_col="image_id",
                                              y_col="dx",
                                              color_mode=color_mode,
                                              target_size=target_size,
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=False
                                              )
val_datagen = ImageDataGenerator(rescale=rescale)
val_set = val_datagen.flow_from_dataframe(val_df_unique_augmented,
                                          directory="dataverse_files/HAM10000_images_augmented",
                                          x_col="image_id",
                                          y_col="dx",
                                          color_mode=color_mode,
                                          target_size=target_size,
                                          batch_size=batch_size,
                                          class_mode='categorical',
                                          shuffle=False
                                          )
test_datagen = ImageDataGenerator(rescale=rescale)
test_set = test_datagen.flow_from_dataframe(test_df,
                                            directory="dataverse_files/ISIC2018_Task3_Test_Images",
                                            x_col="image_id",
                                            y_col="dx",
                                            color_mode=color_mode,
                                            target_size=target_size,
                                            batch_size=batch_size,
                                            class_mode='categorical',
                                            shuffle=False
                                            )
# Out:
# Found 6221 validated image filenames belonging to 7 classes.
# Found 691 validated image filenames belonging to 7 classes.
# Found 1511 validated image filenames belonging to 7 classes.

# %%
no_of_classes = 7

model = Sequential()

#1st CNN layer
model.add(Conv2D(filters=32, 
                 kernel_size=(3,3), 
                 input_shape=(target_size[0],target_size[1],3)
                 ))
model.add(BatchNormalization()) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

#2nd CNN layer
model.add(Conv2D(filters=64, 
                 kernel_size=(5,5),
                ))
model.add(BatchNormalization()) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

# Passing it to a Fully Connected layer
model.add(Flatten())

#1st Fully Connected layer
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.25))


#2nd Fully Connected layer
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dropout(0.25))


#Last Layer
model.add(Dense(no_of_classes, activation='softmax'))

#model.add(GlobalAveragePooling2D()) # for last cnn layer before flatten


#model.add(BatchNormalization()) # after CNN layers or all layers except output layer (before activation)

#model.add(Dropout(0.25)) # after activation

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        896
#
#  batch_normalization (BatchN  (None, 26, 26, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 26, 26, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          51264
#
#  batch_normalization_1 (Batc  (None, 9, 9, 64)         256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 9, 9, 64)          0
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  activation_3 (Activation)   (None, 32)                0
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 120,455
# Trainable params: 120,263
# Non-trainable params: 192
# _________________________________________________________________

# %%
def loss_plot(model, history, now, save=True):
    # convert the history.history dict to a pandas DataFrame:
    if type(history) is not pd.DataFrame:
        history = pd.DataFrame(history)
    if save == True:
        hist_csv_file = f'model-comparison/{now}/history.csv'
        with open(hist_csv_file, mode='w') as f:
            history.to_csv(f) 
    epochs = range(1, history.shape[0]+1)
    plt.figure(figsize=(5, 2))
    plt.plot(epochs, history['accuracy'], label='Accuracy')
    plt.plot(epochs, history['val_accuracy'], label='Validation Accuracy')
    max_val_acc_epoch = np.argmax(history['val_accuracy']) + 1
    max_val_acc = history['val_accuracy'][max_val_acc_epoch-1]
    label='Best Epoch = '+str(max_val_acc_epoch)+'\nVal. Acc. = '+str((max_val_acc*100).round(2))+ '%'
    plt.plot(max_val_acc_epoch, max_val_acc, 'ro', label=label)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.xlim([0, history.shape[0]+0.1])
    plt.ylim([0.5, 1])
    plt.title('Training and Validation Accuracy')
    plt.legend(loc='upper left')
    if save == True:
        plt.savefig(f'model-comparison/{now}/val-acc.png')
    plt.show()

# %%
def EvaluateModel(model, test_set, str1, now, save = True):
    
    print('\n PREDICTING LABELS OF TEST IMAGES')
    result = model.predict(test_set)
    y_pred = np.argmax(result, axis=1)
    
    if save==True:
        #save y_pred to csv file
        np.savetxt('model-comparison/{}/pred.csv'.format(now), y_pred, delimiter=',', fmt='%d')
    
    y_true = test_set.classes # List containing true labels for each image.

    # Understanding classification power of model on each class    
    report = classification_report(y_true, y_pred, target_names=test_set.class_indices.keys())
    report_d = pd.DataFrame(classification_report(y_true, y_pred, output_dict=True, target_names=test_set.class_indices.keys())).transpose()
    report_d['support']['accuracy'] = report_d['support']['macro avg']

    annot = report_d.copy()
    annot.iloc[:, 0:3] = (annot.iloc[:, 0:3]*100).applymap('{:.2f}'.format) + ' %'
    annot.iloc[7, 1] = ''
    annot.iloc[7, 0] = ''
    annot['support'] = annot['support'].astype(int)

    # how to save report as image
    norm = Normalize(-1,1)
    cmap = LinearSegmentedColormap.from_list("", [[norm(-1.0), "white"],[norm( 1.0), "white"]])
    plot = sns.heatmap(report_d, annot=annot, cmap=cmap, cbar=False, fmt='')
    fig = plot.get_figure()
    if save==True:
        fig.savefig('model-comparison/{}/report.png'.format(now))
    
    f1_score = ((report_d['f1-score']['weighted avg']*100000//10)/100)
    accuracy = ((report_d['f1-score']['accuracy']*100000//10)/100)
    print('\nAccuracy of model prediction is: {:.2f} %'.format(accuracy))
    print('\nF1-score of model prediction is: {:.2f} %'.format(f1_score))

    cm = confusion_matrix(y_true, y_pred)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, 
                              display_labels=test_set.class_indices.keys()
                              )
    disp.plot(cmap='Reds')
    disp.ax_.set_title('Confusion Matrix')
    plt.show()
    if save==True:
        disp.figure_.savefig('model-comparison/{}/cm.png'.format(now))

# %%
# Train new model and evaluate
now = datetime.datetime.now().strftime("%d-%m-%H-%M")

#class_weights = class_weight.compute_class_weight(class_weight='balanced',classes=np.unique(train_set.classes), y=train_set.classes)
#class_weights_dict=dict(zip(np.unique(train_set.classes),class_weights))
#keras.utils.set_random_seed(42)

# Define the optimizer
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
#optimizer= Adam(learning_rate = 0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
checkpoint = ModelCheckpoint(f"model-comparison/{now}/model.h5", monitor='val_accuracy', save_best_only=True, mode='max')
# batch_size*steps_per_epoch = total number of images
history = model.fit(train_set, #steps_per_epoch=50, #validation_steps = 15, 
                    epochs=50,
                    validation_data = val_set,
                    callbacks=[learning_rate_reduction, checkpoint],
                    #class_weight=class_weights_dict,
                    )
os.system(finish_sound)
with open('model-comparison/last.txt', 'w') as f:
    f.write(str(now))
loss_plot(model, history.history, now)
# Out:
# Epoch 1/50
# 98/98 [==============================] - 39s 383ms/step - loss: 2.0242 - accuracy: 0.1815 - val_loss: 1.9471 - val_accuracy: 0.1795 - lr: 0.0010
# Epoch 2/50
# 98/98 [==============================] - 37s 382ms/step - loss: 1.8995 - accuracy: 0.2336 - val_loss: 1.9088 - val_accuracy: 0.2200 - lr: 0.0010
# Epoch 3/50
# 98/98 [==============================] - 38s 391ms/step - loss: 1.8301 - accuracy: 0.2607 - val_loss: 1.8828 - val_accuracy: 0.1925 - lr: 0.0010
# Epoch 4/50
# 98/98 [==============================] - 38s 385ms/step - loss: 1.7378 - accuracy: 0.3154 - val_loss: 1.7728 - val_accuracy: 0.3169 - lr: 0.0010
# Epoch 5/50
# 98/98 [==============================] - 38s 391ms/step - loss: 1.6827 - accuracy: 0.3392 - val_loss: 1.6678 - val_accuracy: 0.3849 - lr: 0.0010
# Epoch 6/50
# 98/98 [==============================] - 38s 390ms/step - loss: 1.6024 - accuracy: 0.3789 - val_loss: 1.6721 - val_accuracy: 0.3575 - lr: 0.0010
# Epoch 7/50
# 98/98 [==============================] - 38s 388ms/step - loss: 1.4823 - accuracy: 0.4300 - val_loss: 1.5592 - val_accuracy: 0.3849 - lr: 0.0010
# Epoch 8/50
# 98/98 [==============================] - 38s 389ms/step - loss: 1.4338 - accuracy: 0.4541 - val_loss: 1.5735 - val_accuracy: 0.3965 - lr: 0.0010
# Epoch 9/50
# 98/98 [==============================] - 38s 392ms/step - loss: 1.3410 - accuracy: 0.4753 - val_loss: 1.6082 - val_accuracy: 0.3748 - lr: 0.0010
# Epoch 10/50
# 98/98 [==============================] - 38s 393ms/step - loss: 1.2820 - accuracy: 0.5043 - val_loss: 1.4879 - val_accuracy: 0.4399 - lr: 0.0010
# Epoch 11/50
# 98/98 [==============================] - 38s 390ms/step - loss: 1.2369 - accuracy: 0.5190 - val_loss: 1.5422 - val_accuracy: 0.4385 - lr: 0.0010
# Epoch 12/50
# 98/98 [==============================] - 38s 389ms/step - loss: 1.1565 - accuracy: 0.5498 - val_loss: 1.6086 - val_accuracy: 0.3994 - lr: 0.0010
# Epoch 13/50
# 98/98 [==============================] - ETA: 0s - loss: 1.1783 - accuracy: 0.5375
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 98/98 [==============================] - 38s 388ms/step - loss: 1.1783 - accuracy: 0.5375 - val_loss: 1.5678 - val_accuracy: 0.4255 - lr: 0.0010
# Epoch 14/50
# 98/98 [==============================] - 38s 391ms/step - loss: 1.0797 - accuracy: 0.5809 - val_loss: 1.5124 - val_accuracy: 0.4356 - lr: 5.0000e-04
# Epoch 15/50
# 98/98 [==============================] - 38s 390ms/step - loss: 1.0308 - accuracy: 0.6055 - val_loss: 1.4660 - val_accuracy: 0.4342 - lr: 5.0000e-04
# Epoch 16/50
# 98/98 [==============================] - 38s 390ms/step - loss: 1.0211 - accuracy: 0.6031 - val_loss: 1.5214 - val_accuracy: 0.4559 - lr: 5.0000e-04
# Epoch 17/50
# 98/98 [==============================] - 38s 394ms/step - loss: 0.9923 - accuracy: 0.6186 - val_loss: 1.3950 - val_accuracy: 0.4834 - lr: 5.0000e-04
# Epoch 18/50
# 98/98 [==============================] - 38s 394ms/step - loss: 0.9872 - accuracy: 0.6195 - val_loss: 1.5861 - val_accuracy: 0.4457 - lr: 5.0000e-04
# Epoch 19/50
# 98/98 [==============================] - 38s 390ms/step - loss: 0.9578 - accuracy: 0.6312 - val_loss: 1.4475 - val_accuracy: 0.4472 - lr: 5.0000e-04
# Epoch 20/50
# 98/98 [==============================] - ETA: 0s - loss: 0.9343 - accuracy: 0.6409
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 98/98 [==============================] - 38s 391ms/step - loss: 0.9343 - accuracy: 0.6409 - val_loss: 1.7069 - val_accuracy: 0.4081 - lr: 5.0000e-04
# Epoch 21/50
# 98/98 [==============================] - 39s 395ms/step - loss: 0.8996 - accuracy: 0.6552 - val_loss: 1.3278 - val_accuracy: 0.5398 - lr: 2.5000e-04
# Epoch 22/50
# 98/98 [==============================] - 39s 396ms/step - loss: 0.8854 - accuracy: 0.6591 - val_loss: 1.4412 - val_accuracy: 0.4776 - lr: 2.5000e-04
# Epoch 23/50
# 98/98 [==============================] - 38s 392ms/step - loss: 0.8790 - accuracy: 0.6607 - val_loss: 1.3321 - val_accuracy: 0.5297 - lr: 2.5000e-04
# Epoch 24/50
# 98/98 [==============================] - ETA: 0s - loss: 0.8649 - accuracy: 0.6652
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 98/98 [==============================] - 39s 392ms/step - loss: 0.8649 - accuracy: 0.6652 - val_loss: 1.4472 - val_accuracy: 0.4703 - lr: 2.5000e-04
# Epoch 25/50
# 98/98 [==============================] - 39s 395ms/step - loss: 0.8395 - accuracy: 0.6783 - val_loss: 1.3603 - val_accuracy: 0.5253 - lr: 1.2500e-04
# Epoch 26/50
# 98/98 [==============================] - 42s 425ms/step - loss: 0.8364 - accuracy: 0.6737 - val_loss: 1.3180 - val_accuracy: 0.5427 - lr: 1.2500e-04
# Epoch 27/50
# 98/98 [==============================] - 42s 432ms/step - loss: 0.8248 - accuracy: 0.6841 - val_loss: 1.4085 - val_accuracy: 0.4920 - lr: 1.2500e-04
# Epoch 28/50
# 98/98 [==============================] - 39s 397ms/step - loss: 0.8326 - accuracy: 0.6767 - val_loss: 1.4145 - val_accuracy: 0.4964 - lr: 1.2500e-04
# Epoch 29/50
# 98/98 [==============================] - ETA: 0s - loss: 0.8214 - accuracy: 0.6769
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 98/98 [==============================] - 39s 398ms/step - loss: 0.8214 - accuracy: 0.6769 - val_loss: 1.3561 - val_accuracy: 0.5123 - lr: 1.2500e-04
# Epoch 30/50
# 98/98 [==============================] - 40s 403ms/step - loss: 0.8217 - accuracy: 0.6882 - val_loss: 1.3530 - val_accuracy: 0.5210 - lr: 6.2500e-05
# Epoch 31/50
# 98/98 [==============================] - 39s 400ms/step - loss: 0.8061 - accuracy: 0.6899 - val_loss: 1.3168 - val_accuracy: 0.5268 - lr: 6.2500e-05
# Epoch 32/50
# 98/98 [==============================] - ETA: 0s - loss: 0.8068 - accuracy: 0.6923
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 98/98 [==============================] - 39s 404ms/step - loss: 0.8068 - accuracy: 0.6923 - val_loss: 1.3352 - val_accuracy: 0.5297 - lr: 6.2500e-05
# Epoch 33/50
# 98/98 [==============================] - 40s 415ms/step - loss: 0.8128 - accuracy: 0.6845 - val_loss: 1.2946 - val_accuracy: 0.5326 - lr: 3.1250e-05
# Epoch 34/50
# 98/98 [==============================] - 46s 473ms/step - loss: 0.8061 - accuracy: 0.6917 - val_loss: 1.2840 - val_accuracy: 0.5441 - lr: 3.1250e-05
# Epoch 35/50
# 98/98 [==============================] - 39s 402ms/step - loss: 0.7991 - accuracy: 0.6933 - val_loss: 1.3043 - val_accuracy: 0.5369 - lr: 3.1250e-05
# Epoch 36/50
# 98/98 [==============================] - 39s 401ms/step - loss: 0.7954 - accuracy: 0.6904 - val_loss: 1.2834 - val_accuracy: 0.5412 - lr: 3.1250e-05
# Epoch 37/50
# 98/98 [==============================] - 40s 409ms/step - loss: 0.7886 - accuracy: 0.6984 - val_loss: 1.2826 - val_accuracy: 0.5470 - lr: 3.1250e-05
# Epoch 38/50
# 98/98 [==============================] - 39s 400ms/step - loss: 0.7977 - accuracy: 0.6944 - val_loss: 1.2874 - val_accuracy: 0.5543 - lr: 3.1250e-05
# Epoch 39/50
# 98/98 [==============================] - 39s 400ms/step - loss: 0.7763 - accuracy: 0.7018 - val_loss: 1.3193 - val_accuracy: 0.5485 - lr: 3.1250e-05
# Epoch 40/50
# 98/98 [==============================] - 40s 406ms/step - loss: 0.7984 - accuracy: 0.6960 - val_loss: 1.2772 - val_accuracy: 0.5615 - lr: 3.1250e-05
# Epoch 41/50
# 98/98 [==============================] - 40s 412ms/step - loss: 0.7973 - accuracy: 0.6906 - val_loss: 1.2692 - val_accuracy: 0.5485 - lr: 3.1250e-05
# Epoch 42/50
# 98/98 [==============================] - 39s 401ms/step - loss: 0.7992 - accuracy: 0.6988 - val_loss: 1.2843 - val_accuracy: 0.5543 - lr: 3.1250e-05
# Epoch 43/50
# 98/98 [==============================] - ETA: 0s - loss: 0.7881 - accuracy: 0.6959
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 98/98 [==============================] - 40s 407ms/step - loss: 0.7881 - accuracy: 0.6959 - val_loss: 1.2758 - val_accuracy: 0.5499 - lr: 3.1250e-05
# Epoch 44/50
# 98/98 [==============================] - 40s 413ms/step - loss: 0.7603 - accuracy: 0.7081 - val_loss: 1.2811 - val_accuracy: 0.5427 - lr: 1.5625e-05
# Epoch 45/50
# 98/98 [==============================] - 40s 407ms/step - loss: 0.7957 - accuracy: 0.6938 - val_loss: 1.2852 - val_accuracy: 0.5470 - lr: 1.5625e-05
# Epoch 46/50
# 98/98 [==============================] - ETA: 0s - loss: 0.7892 - accuracy: 0.6907
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1e-05.
# 98/98 [==============================] - 39s 401ms/step - loss: 0.7892 - accuracy: 0.6907 - val_loss: 1.2856 - val_accuracy: 0.5441 - lr: 1.5625e-05
# Epoch 47/50
# 98/98 [==============================] - 43s 439ms/step - loss: 0.7868 - accuracy: 0.7033 - val_loss: 1.2791 - val_accuracy: 0.5514 - lr: 1.0000e-05
# Epoch 48/50
# 98/98 [==============================] - 40s 404ms/step - loss: 0.7735 - accuracy: 0.7005 - val_loss: 1.2787 - val_accuracy: 0.5528 - lr: 1.0000e-05
# Epoch 49/50
# 98/98 [==============================] - 40s 407ms/step - loss: 0.7783 - accuracy: 0.7023 - val_loss: 1.2761 - val_accuracy: 0.5543 - lr: 1.0000e-05
# Epoch 50/50
# 98/98 [==============================] - 43s 436ms/step - loss: 0.7881 - accuracy: 0.6989 - val_loss: 1.2840 - val_accuracy: 0.5470 - lr: 1.0000e-05

# %%
model = load_model(f"model-comparison/{now}/model.h5")
EvaluateModel(model, val_set, 'val', now)
EvaluateModel(model, test_set, 'test', now)
# Out:
#  PREDICTING LABELS OF TEST IMAGES
# 11/11 [==============================] - 4s 313ms/step
#
# Accuracy of model prediction is: 56.15 %
#
# F1-score of model prediction is: 55.08 %
#  PREDICTING LABELS OF TEST IMAGES
# 24/24 [==============================] - 20s 866ms/step
#
# Accuracy of model prediction is: 51.09 %
#
# F1-score of model prediction is: 54.32 %

# %%
# Load Trained Model and Evaluate
now = open('model-comparison/last.txt', 'r').read() 
#now = '21-11-20-14'
model = load_model(f"model-comparison/{now}/model.h5")
history = pd.read_csv(f'model-comparison/{now}/history.csv')
loss_plot(model, history, now, save=False)
EvaluateModel(model, val_set, 'val', now, save=False)
EvaluateModel(model, test_set, 'test', now, save=False)
# Out:
#  PREDICTING LABELS OF TEST IMAGES
# 11/11 [==============================] - 4s 326ms/step
#
# Accuracy of model prediction is: 56.15 %
#
# F1-score of model prediction is: 55.08 %
#  PREDICTING LABELS OF TEST IMAGES
# 24/24 [==============================] - 10s 397ms/step
#
# Accuracy of model prediction is: 51.09 %
#
# F1-score of model prediction is: 54.32 %
